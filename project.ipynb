# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')

lowestPrice = ds['price'].max()

address = ds[(ds['price'] == lowestPrice)]['address'].item()

print('The house with address ' + str(address) + ' is the most expensive and its price is ' + str(lowestPrice) + ' USD')
# Out:
# The house with address El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')

# remove all zeroes
ds = ds[(ds['price'] != 0)]

lowestPrice = ds['price'].min()

address = ds[(ds['price'] == lowestPrice)]['address'].item()

print('The house with address ' + str(address) + ' is the cheapest and its price is ' + str(lowestPrice) + ' USD')
# Out:
# The house with address Berlin, Coslada is the cheapest and its price is 600 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')

# remove all zeroes
ds = ds[(ds['surface'] != 0)]

biggestSurface = ds['surface'].max()
smallestSurface = ds['surface'].min()

addressForBiggestSurface = ds[(ds['surface'] == biggestSurface)]['address'].item()
addressForSmallestSurface = ds[(ds['surface'] == smallestSurface)]['address'].item()

print('The biggest house is located on ' + str(addressForBiggestSurface) + ' and its surface is ' + str(biggestSurface) + ' meters')
print('The smallest house is located on ' + str(addressForSmallestSurface) + ' and its surface is ' + str(smallestSurface) + ' meters')
# Out:
# The biggest house is located on Sevilla la Nueva and its surface is 249000.0 meters
# The smallest house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')

print(ds['level5'].to_list())
# Out:
# ['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte', 'Fuenlabrada', 'Arganda del Rey', 'Las Rozas de Madrid', 'Las Rozas de Madrid', 'Las Rozas de Madrid', 'Las Rozas de Madrid', ' Madrid Capital', ' Madrid Capital', 'Villaviciosa de Odón', 'Pinto', 'Valdemoro', 'Navalcarnero', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Pozuelo de Alarcón', 'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes', ' Madrid Capital', 'Rivas-vaciamadrid', 'Alpedrete', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Móstoles', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'San Fernando de Henares', 'Coslada', ' Madrid Capital', 'Becerril de la Sierra', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Alcalá de Henares', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Pinto', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Chinchón', ' Madrid Capital', 'Parla', ' Madrid Capital', 'Parla', ' Madrid Capital', ' Madrid Capital', 'Alcorcón', ' Madrid Capital', ' Madrid Capital', 'Pozuelo de Alarcón', 'El Escorial', 'Pozuelo de Alarcón', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Leganés', 'Parla', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Boadilla del Monte', 'Pedrezuela', 'Las Rozas de Madrid', 'Las Rozas de Madrid', 'Majadahonda', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'Las Rozas de Madrid', 'Villanueva del Pardillo', 'Alcorcón', 'Torrelodones', ' Madrid Capital', ' Madrid Capital', 'Moralzarzal', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'San Sebastián de los Reyes', 'Mejorada del Campo', 'Coslada', 'Coslada', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Aranjuez', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Moralzarzal', ' Madrid Capital', 'Navalcarnero', ' Madrid Capital', 'Villanueva del Pardillo', ' Madrid Capital', 'Rivas-vaciamadrid', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Alcalá de Henares', 'Alcalá de Henares', 'Corpa', 'Alcalá de Henares', ' Madrid Capital', 'Pozuelo de Alarcón', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Móstoles', 'Móstoles', 'Móstoles', ' Madrid Capital', ' Madrid Capital', 'Valdemoro', ' Madrid Capital', 'Fuenlabrada', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Navalcarnero', ' Madrid Capital', ' Madrid Capital', 'Getafe', 'Las Rozas de Madrid', 'Majadahonda', 'Majadahonda', 'Las Rozas de Madrid', 'Las Rozas de Madrid', 'Villanueva del Pardillo', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Velilla de San Antonio', ' Madrid Capital', ' Madrid Capital', 'Leganés', 'Majadahonda', ' Madrid Capital', ' Madrid Capital', 'Leganés', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Parla', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Valdemoro', 'Valdemoro', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Fuenlabrada', ' Madrid Capital', ' Madrid ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
import numpy as np

ds = pd.read_csv('assets/real_estate.csv', sep=';')

# # find null columns
# dsNullColumns = ds.loc[:, ds.isnull().all()]

# # remove null columns
# ds = ds.drop(columns=dsNullColumns.columns, axis=1)

print(ds.isnull().any(axis=1).any(axis=0))

for index, row in ds.iterrows():
    nullColumns = np.where(row.isnull())
    columnList = list(map(lambda x: ds.columns[x].values, nullColumns))
    print(str(index) + '/' + str(columnList[0]))
# Out:
# True
# 0/['level6' 'level8']
# 1/['surface' 'level6' 'level8']
# 2/['level6' 'level8']
# 3/['level6' 'level8']
# 4/['level6' 'level8']
# 5/['level6' 'level8']
# 6/['level6' 'level8']
# 7/['level6' 'level8']
# 8/['level6' 'level8']
# 9/['phone_realEstate' 'level4' 'level6']
# 10/['level4' 'level6']
# 11/['level6' 'level8']
# 12/['level6' 'level8']
# 13/['level6' 'level8']
# 14/['level6' 'level8']
# 15/['level4' 'level6']
# 16/['level4' 'level6']
# 17/['level4' 'level6']
# 18/['level6' 'level8']
# 19/['level6' 'level8']
# 20/['phone_realEstate' 'level6' 'level7' 'level8']
# 21/['phone_realEstate' 'level7' 'level8']
# 22/['phone_realEstate' 'level4' 'level6']
# 23/['phone_realEstate' 'level6' 'level8']
# 24/['phone_realEstate' 'level6' 'level7' 'level8']
# 25/['phone_realEstate' 'level4' 'level6']
# 26/['phone_realEstate' 'level4' 'level6']
# 27/['phone_realEstate' 'level4' 'level6']
# 28/['phone_realEstate' 'rooms' 'bathrooms' 'level6' 'level8']
# 29/['level4' 'level6']
# 30/['level4' 'level6']
# 31/['level4' 'level6']
# 32/['level6' 'level8']
# 33/['level6' 'level8']
# 34/['level4' 'level6']
# 35/['level6' 'level7' 'level8']
# 36/['level4' 'level6']
# 37/['level4' 'level6']
# 38/['level4' 'level6']
# 39/['level4' 'level6']
# 40/['level4' 'level6']
# 41/['level4' 'level6']
# 42/['level4' 'level6']
# 43/['level4' 'level6']
# 44/['level4' 'level6']
# 45/['level6' 'level8']
# 46/['level4' 'level6']
# 47/['level4' 'level6']
# 48/['level4' 'level6']
# 49/['level4' 'level6']
# 50/['level4' 'level6']
# 51/['level4' 'level6']
# 52/['level4' 'level6']
# 53/['level4' 'level6']
# 54/['level4' 'level6']
# 55/['level4' 'level6']
# 56/['level6' 'level8']
# 57/['level4' 'level6']
# 58/['level4' 'level6']
# 59/['level4' 'level6']
# 60/['level4' 'level6']
# 61/['level4' 'level6']
# 62/['level4' 'level6']
# 63/['level4' 'level6']
# 64/['level4' 'level6']
# 65/['level4' 'level6']
# 66/['level4' 'level6']
# 67/['level4' 'level6']
# 68/['level4' 'level6']
# 69/['level4' 'level6']
# 70/['level4' 'level6']
# 71/['level4' 'level6']
# 72/['level4' 'level6']
# 73/['level4' 'level6']
# 74/['level4' 'level6']
# 75/['level4' 'level6']
# 76/['level4' 'level6']
# 77/['level4' 'level6']
# 78/['level6' 'level7' 'level8']
# 79/['level4' 'level6']
# 80/['level6' 'level8']
# 81/['level4' 'level6']
# 82/['level6' 'level8']
# 83/['level4' 'level6']
# 84/['level4' 'level6']
# 85/['phone_realEstate' 'level6']
# 86/['level4' 'level6']
# 87/['level4' 'level6']
# 88/['level6' 'level8']
# 89/['level6' 'level8']
# 90/['level6' 'level8']
# 91/['bathrooms' 'level4' 'level6']
# 92/['level4' 'level6']
# 93/['level4' 'level6']
# 94/['level6' 'level8']
# 95/['level6' 'level8']
# 96/['level4' 'level6']
# 97/['level4' 'level6']
# 98/['level4' 'level6']
# 99/['level4' 'level6']
# 100/['level6' 'level8']
# 101/['level6' 'level7' 'level8']
# 102/['level6' 'level8']
# 103/['level6' 'level8']
# 104/['level6' 'level8']
# 105/['level6' 'level8']
# 106/['level6' 'level8']
# 107/['level6' 'level8']
# 108/['level6' 'level8']
# 109/['level6' 'level8']
# 110/['level6' 'level8']
# 111/['level4' 'level6']
# 112/['level4' 'level6']
# 113/['level6' 'level8']
# 114/['level4' 'level6']
# 115/['level4' 'level6']
# 116/['level4' 'level6']
# 117/['level4' 'level6']
# 118/['level8']
# 119/['level6' 'level7' 'level8']
# 120/['level6' 'level8']
# 121/['level6' 'level8']
# 122/['phone_realEstate' 'level4' 'level6']
# 123/['level4' 'level6']
# 124/['level4' 'level6']
# 125/['level4' 'level6']
# 126/['level6' 'level8']
# 127/['level4' 'level6']
# 128/['level4' 'level6']
# 129/['level4' 'level6']
# 130/['level4' 'level6']
# 131/['level4' 'level6']
# 132/['level4' 'level6']
# 133/['level4' 'level6']
# 134/['level4' 'level6']
# 135/['level6' 'level8']
# 136/['level4' 'level6']
# 137/['level6' 'level8']
# 138/['phone_realEstate' 'surface' 'level4' 'level6']
# 139/['level6' 'level8']
# 140/['level4' 'level6']
# 141/['level6' 'level8']
# 142/['level4' 'level6']
# 143/['level4' 'level6']
# 144/['level4' 'level6']
# 145/['level6' 'level8']
# 146/['level6' 'level8']
# 147/['level6' 'level7' 'level8']
# 148/['level6' 'level8']
# 149/['level4' 'level6']
# 150/['level6' 'level8']
# 151/['level4' 'level6']
# 152/['level4' 'level6']
# 153/['level4' 'level6']
# 154/['level6' 'level8']
# 155/['level6' 'level8']
# 156/['level6' 'level8']
# 157/['phone_realEstate' 'surface' 'level4' 'level6']
# 158/['level4' 'level6']
# 159/['level6' 'level8']
# 160/['level4' 'level6']
# 161/['level6' 'level8']
# 162/['level4' 'level6']
# 163/['level4' 'level6']
# 164/['level4' 'level6']
# 165/['level4' 'level6']
# 166/['level6' 'level8']
# 167/['level4' 'level6']
# 168/['level4' 'level6']
# 169/['level6' 'level8']
# 170/['level6' 'level8']
# 171/['level6' 'level8']
# 172/['level6' 'level8']
# 173/['level6' 'level8']
# 174/['level6' 'level8']
# 175/['level6' 'level8']
# 176/['surface' 'level4' 'level6']
# 177/['rooms' 'bathrooms' 'surface' 'level4' 'level6']
# 178/['level4' 'level6']
# 179/['level4' 'level6']
# 180/['level4' 'level6']
# 181/['level4' 'level6']
# 182/['surface' 'level4' 'level6']
# 183/['level4' 'level6']
# 184/['level4' 'level6']
# 185/['level4' 'level6']
# 186/['level6' 'level7' 'level8']
# 187/['level4' 'level6']
# 188/['level4' 'level6']
# 189/['level6' 'level8']
# 190/['level6' 'level8']
# 191/['level4' 'level6']
# 192/['bathrooms' 'level4' 'level6']
# 193/['level6' 'level8']
# 194/['level4' 'level6']
# 195/['level4' 'level6']
# 196/['level4' 'level6']
# 197/['level4' 'level6']
# 198/['level4' 'level6']
# 199/['level4' 'level6']
# 200/['level6' 'level8']
# 201/['level4' 'level6']
# 202/['level4' 'level6']
# 203/['level4' 'level6']
# 204/['level4' 'level6']
# 205/['level4' 'level6']
# 206/['level4' 'level6']
# 207/['level4' 'level6']
# 208/['level4' 'level6']
# 209/['level6' 'level8']
# 210/['level6' 'level8']
# 211/['level4' 'level6']
# 212/['level4' 'level6']
# 213/['level4' 'level6']
# 214/['level6' 'level8']
# 215/['level4' 'level6']
# 216/['level4' 'level6']
# 217/['level6' 'level7' 'level8']
# 218/['phone_realEstate' 'level4' 'level6']
# 219/['level6' 'level8']
# 220/['level6' 'level8']
# 221/['phone_realEstate' 'level4' 'level6']
# 222/['phone_realEstate' 'level4' 'level6']
# 223/['level4' 'level6']
# 224/['level4' 'level6']
# 225/['level4' 'level6']
# 226/['level4' 'level6']
# 227/['level4' 'level6']
# 228/['level4' 'level6']
# 229/['level4' 'level6']
# 230/['level6' 'level8']
# 231/['level4' 'level6']
# 232/['level6' 'level8']
# 233/['level6' 'level8']
# 234/['level4' 'level6']
# 235/['level4' 'level6']
# 236/['level6' 'level8']
# 237/['level4' 'level6']
# 238/['level8']
# 239/['level6' 'level7' 'level8']
# 240/['level4' 'level6']
# 241/['level6' 'level8']
# 242/['phone_realEstate' 'level4' 'level6']
# 243/['level4' 'level6']
# 244/['level6' 'level7' 'level8']
# 245/['level4' 'level6']
# 246/['level4' 'level6']
# 247/['phone_realEstate' 'level4' 'level6']
# 248/['level7' 'level8']
# 249/['level6' 'level8']
# 250/['level6' 'level8']
# 251/['surface' 'level4' 'level6']
# 252/['level4' 'level6']
# 253/['level4' 'level6']
# 254/['level4' 'level6']
# 255/['level4' 'level6']
# 256/['level4' 'level6']
# 257/['phone_realEstate' 'level6' 'level8']
# 258/['level4' 'level6']
# 259/['level6' 'level8']
# 260/['level6' 'level8']
# 261/['level6' 'level8']
# 262/['level6' 'level8']
# 263/['level4' 'level6']
# 264/['surface' 'level6' 'level8']
# 265/['level6' 'level8']
# 266/['level4' 'level6']
# 267/['level6' 'level8']
# 268/['level6' 'level8']
# 269/['level6' 'level8']
# 270/['level4' 'level6']
# 271/['level4' 'level6']
# 272/['level6' 'level8']
# 273/['level4' 'level6']
# 274/['level7' 'level8']
# 275/['level4' 'level6']
# 276/['level4' 'level6']
# 277/['level6' 'level8']
# 278/['level4' 'level6']
# 279/['level4' 'level6']
# 280/['surface' 'level4' 'level6']
# 281/['level6' 'level8']
# 282/['level8']
# 283/['level8']
# 284/['level4' 'level6']
# 285/['level4' 'level6']
# 286/['level4' 'level6']
# 287/['level6' 'level8']
# 288/['level4' 'level6']
# 289/['level4' 'level6']
# 290/['level6' 'level8']
# 291/['level6' 'level8']
# 292/['level4' 'level6']
# 293/['level6' 'level8']
# 294/['surface' 'level4' 'level6']
# 295/['level4' 'level6']
# 296/['level6' 'level7' 'level8']
# 297/['level4' 'level6']
# 298/['level4' 'level6']
# 299/['level6' 'level8']
# 300/['phone_realEstate' 'level4' 'level6']
# 301/['level6' 'level8']
# 302/['level4' 'level6']
# 303/['level4' 'level6']
# 304/['bathrooms' 'level4' 'level6']
# 305/['level4' 'level6']
# 306/['level4' 'level6']
# 307/['level4' 'level6']
# 308/['level6' 'level8']
# 309/['surface' 'level6' 'level8']
# 310/['level4' 'level6']
# 311/['level4' 'level6']
# 312/['level6' 'level8']
# 313/['level6' 'level8']
# 314/['level6' 'level7' 'level8']
# 315/['surface' 'level4' 'level6']
# 316/['surface' 'level4' 'level6']
# 317/['level6' 'level8']
# 318/['level4' 'level6']
# 319/['level4' 'level6']
# 320/['level4' 'level6']
# 321/['level4' 'level6']
# 322/['level6' 'level8']
# 323/['level4' 'level6']
# 324/['level4' 'level6']
# 325/['level4' 'level6']
# 326/['level6' 'level8']
# 327/['level6' 'level7' 'level8']
# 328/['level6' 'level8']
# 329/['level7' 'level8']
# 330/['surface' 'level6' 'level8']
# 331/['level4' 'level6']
# 332/['level4' 'level6']
# 333/['level6' 'level8']
# 334/['level4' 'level6']
# 335/['level4' 'level6']
# 336/['level6' 'level8']
# 337/['level4' 'level6']
# 338/['level4' 'level6']
# 339/['level4' 'level6']
# 340/['level4' 'level6']
# 341/['level4' 'level6']
# 342/['level4' 'level6']
# 343/['level4' 'level6']
# 344/['level4' 'level6']
# 345/['level6' 'level8']
# 346/['level4' 'level6']
# 347/['level6' 'level8']
# 348/['level4' 'level6']
# 349/['level8']
# 350/['level4' 'level6']
# 351/['level4' 'level6']
# 352/['level6' 'level8']
# 353/['level4' 'level6']
# 354/['level6' 'level8']
# 355/['level6' 'level8']
# 356/['level4' 'level6']
# 357/['level4' 'level6']
# 358/['level6' 'level8']
# 359/['level6' 'level8']
# 360/['level4' 'level6']
# 361/['level6' 'level7' 'level8']
# 362/['level4' 'level6']
# 363/['level6' 'level8']
# 364/['level8']
# 365/['level6' 'level7' 'level8']
# 366/['level6' 'level8']
# 367/['level4' 'level6']
# 368/['level4' 'level6']
# 369/['level4' 'level6']
# 370/['level8']
# 371/['level4' 'level6']
# 372/['level4' 'level6']
# 373/['level4' 'level6']
# 374/['level4' 'level6']
# 375/['level6' 'level8']
# 376/['level6' 'level8']
# 377/['level6' 'level8']
# 378/['level4' 'level6']
# 379/['level4' 'level6']
# 380/['level6' 'level8']
# 381/['level6' 'level8']
# 382/['level4' 'level6']
# 383/['surface' 'level4' 'level6']
# 384/['level4' 'level6']
# 385/['level6' 'level8']
# 386/['level6' 'level8']
# 387/['level6' 'level8']
# 388/['level6' 'level8']
# 389/['level6' 'level8']
# 390/['phone_realEstate' 'level6' 'level8']
# 391/['phone_realEstate' 'level4' 'level6']
# 392/['level4' 'level6']
# 393/['level4' 'level6']
# 394/['level4' 'level6']
# 395/['level8']
# 396/['level4' 'level6']
# 397/['level4' 'level6']
# 398/['level4' 'level6']
# 399/['level6' 'level7' 'level8']
# 400/['level4' 'level6']
# 401/['level4' 'level6']
# 402/['level4' 'level6']
# 403/['level4' 'level6']
# 404/['level4' 'level6']
# 405/['level4' 'level6']
# 406/['level4' 'level6']
# 407/['level4' 'level6']
# 408/['level6' 'level8']
# 409/['level6' 'level8']
# 410/['level6' 'level8']
# 411/['level6' 'level8']
# 412/['level4' 'level6']
# 413/['level6' 'level7' 'level8']
# 414/['level4' 'level6']
# 415/['level4' 'level6']
# 416/['level4' 'level6']
# 417/['bathrooms' 'level4' 'level6']
# 418/['level4' 'level6']
# 419/['level4' 'level6']
# 420/['level4' 'level6']
# 421/['level6' 'level8']
# 422/['surface' 'level4' 'level6']
# 423/['surface' 'level6' 'level8']
# 424/['level6' 'level8']
# 425/['level4' 'level6']
# 426/['level4' 'level6']
# 427/['level4' 'level6']
# 428/['level4' 'level6']
# 429/['level6' 'level8']
# 430/['phone_realEstate' 'surface' 'level4' 'level6']
# 431/['level4' 'level6']
# 432/['level8']
# 433/['level4' 'level6']
# 434/['phone_realEstate' 'level4' 'level6']
# 435/['phone_realEstate' 'level4' 'level6']
# 436/['phone_realEstate' 'level4' 'level6']
# 437/['level6' 'level8']
# 438/['level6' 'level8']
# 439/['level4' 'level6']
# 440/['phone_realEstate' 'level4' 'level6']
# 441/['phone_realEstate' 'level4' 'level6']
# 442/['level4' 'level6']
# 443/['level4' 'level6']
# 444/['level4' 'level6']
# 445/['level4' 'level6']
# 446/['surface' 'level6' 'level8']
# 447/['level6' 'level8']
# 448/['level6' 'level8']
# 449/['level8']
# 450/['level6' 'level8']
# 451/['level4' 'level6']
# 452/['level4' 'level6']
# 453/['level6' 'level8']
# 454/['phone_realEstate' 'level4' 'level6']
# 455/['level6' 'level8']
# 456/['level4' 'level6']
# 457/['phone_realEstate' 'level6' 'level8']
# 458/['level4' 'level6']
# 459/['level4' 'level6']
# 460/['level8']
# 461/['level4' 'level6']
# 462/['level6' 'level7' 'level8']
# 463/['level4' 'level6']
# 464/['level6' 'level8']
# 465/['level6' 'level8']
# 466/['level6' 'level8']
# 467/['level6' 'level8']
# 468/['level6' 'level8']
# 469/['level4' 'level6']
# 470/['level4' 'level6']
# 471/['level6' 'level8']
# 472/['level6' 'level8']
# 473/['level4' 'level6']
# 474/['level6' 'level8']
# 475/['level6' 'level8']
# 476/['level6' 'level8']
# 477/['level6']
# 478/['level6' 'level8']
# 479/['level6' 'level8']
# 480/['level6' 'level8']
# 481/['surface' 'level6' 'level8']
# 482/['level4' 'level6']
# 483/['level6' 'level8']
# 484/['level4' 'level6']
# 485/['level6' 'level7' 'level8']
# 486/['level6' 'level8']
# 487/['level4' 'level6']
# 488/['level6' 'level8']
# 489/['phone_realEstate' 'level4' 'level6']
# 490/['rooms' 'level4' 'level6']
# 491/['level4' 'level6']
# 492/['level6' 'level8']
# 493/['level4' 'level6']
# 494/['level6' 'level8']
# 495/['level4' 'level6']
# 496/['level6' 'level8']
# 497/['level6' 'level8']
# 498/['level4' 'level6']
# 499/['level4' 'level6']
# 500/['level4' 'level6']
# 501/['level4' 'level6']
# 502/['rooms' 'level4' 'level6']
# 503/['level6' 'level8']
# 504/['level6' 'level8']
# 505/['level6' 'level8']
# 506/['level4' 'level6']
# 507/['level6' 'level8']
# 508/['level4' 'level6']
# 509/['level6' 'level8']
# 510/['level6' 'level8']
# 511/['level6' 'level8']
# 512/['level6' 'level8']
# 513/['level4' 'level6']
# 514/['level4' 'level6']
# 515/['level6' 'level8']
# 516/['level6' 'level8']
# 517/['level6' 'level8']
# 518/['level6' 'level8']
# 519/['level6' 'level7' 'level8']
# 520/['level4' 'level6']
# 521/['level4' 'level6']
# 522/['level6' 'level8']
# 523/['level6' 'level8']
# 524/['level6' 'level8']
# 525/['level6' 'level8']
# 526/['level6' 'level7' 'level8']
# 527/['level4' 'level6']
# 528/['level6' 'level8']
# 529/['level4' 'level6']
# 530/['level4' 'level6']
# 531/['level4' 'level6']
# 532/['level6' 'level8']
# 533/['level4' 'level6']
# 534/['level4' 'level6']
# 535/['level4' 'level6']
# 536/['level6' 'level8']
# 537/['level4' 'level6']
# 538/['level4' 'level6']
# 539/['level8']
# 540/['level8']
# 541/['level6' 'level8']
# 542/['level4' 'level6']
# 543/['level4' 'level6']
# 544/['level6' 'level8']
# 545/['level6' 'level8']
# 546/['level4' 'level6']
# 547/['level6' 'level8']
# 548/['level4' 'level6']
# 549/['level4' 'level6']
# 550/['level4' 'level6']
# 551/['surface' 'level6' 'level8']
# 552/['level4' 'level6']
# 553/['level6' 'level8']
# 554/['level6' 'level8']
# 555/['level6' 'level8']
# 556/['level6' 'level8']
# 557/['level6' 'level8']
# 558/['level6' 'level8']
# 559/['level6' 'level8']
# 560/['level6' 'level8']
# 561/['level6' 'level8']
# 562/['level6' 'level8']
# 563/['level6' 'level8']
# 564/['level6' 'level8']
# 565/['level6' 'level8']
# 566/['level6' 'level8']
# 567/['level6' 'level8']
# 568/['level6' 'level8']
# 569/['level4' 'level6']
# 570/['level6' 'level8']
# 571/['level6' 'level8']
# 572/['level6' 'level8']
# 573/['level6' 'level8']
# 574/['level6' 'level8']
# 575/['level6' 'level8']
# 576/['level6' 'level8']
# 577/['surface' 'level6' 'level8']
# 578/['level4' 'level6']
# 579/['level6' 'level8']
# 580/['level6' 'level8']
# 581/['level6' 'level8']
# 582/['level6' 'level8']
# 583/['level6' 'level8']
# 584/['level6' 'level8']
# 585/['level4' 'level6']
# 586/['bathrooms' 'level4' 'level6']
# 587/['level4' 'level6']
# 588/['level6' 'level8']
# 589/['level4' 'level6']
# 590/['level6' 'level7' 'level8']
# 591/['level6' 'level7' 'level8']
# 592/['level4' 'level6']
# 593/['level4' 'level6']
# 594/['level6' 'level8']
# 595/['level4' 'level6']
# 596/['level6' 'level8']
# 597/['level4' 'level6']
# 598/['level4' 'level6']
# 599/['level4' 'level6']
# 600/['level6' 'level8']
# 601/['level4' 'level6']
# 602/['level4' 'level6']
# 603/['level4' 'level6']
# 604/['level6' 'level8']
# 605/['level6' 'level8']
# 606/['level6' 'level8']
# 607/['level6' 'level8']
# 608/['level6' 'level8']
# 609/['level6' 'level8']
# 610/['level6' 'level8']
# 611/['level4' 'level6']
# 612/['level4' 'level6']
# 613/['level6' 'level8']
# 614/['level4' 'level6']
# 615/['level4' 'level6']
# 616/['level6' 'level8']
# 617/['level6' 'level8']
# 618/['level4' 'level6']
# 619/['level4' 'level6']
# 620/['level6' 'level8']
# 621/['level4' 'level6']
# 622/['level4' 'level6']
# 623/['level6' 'level8']
# 624/['level6' 'level8']
# 625/['level6' 'level8']
# 626/['level6' 'level8']
# 627/['level6' 'level8']
# 628/['level4' 'level6']
# 629/['level4' 'level6']
# 630/['level6' 'level8']
# 631/['level6' 'level8']
# 632/['level6' 'level8']
# 633/['level4' 'level6']
# 634/['level4' 'level6']
# 635/['level6' 'level8']
# 636/['level8']
# 637/['level4' 'level6']
# 638/['level6' 'level8']
# 639/['level6' 'level8']
# 640/['level4' 'level6']
# 641/['level8']
# 642/['level4' 'level6']
# 643/['level4' 'level6']
# 644/['phone_realEstate' 'level4' 'level6']
# 645/['level6' 'level8']
# 646/['level6' 'level7' 'level8']
# 647/['level8']
# 648/['level6' 'level8']
# 649/['level4' 'level6']
# 650/['level4' 'level6']
# 651/['level6' 'level8']
# 652/['description' 'level4' 'level6']
# 653/['level4' 'level6']
# 654/['level4' 'level6']
# 655/['level6' 'level8']
# 656/['level4' 'level6']
# 657/['level4' 'level6']
# 658/['level6' 'level8']
# 659/['level4' 'level6']
# 660/['level6' 'level8']
# 661/['level4' 'level6']
# 662/['phone_realEstate' 'rooms' 'description' 'level6' 'level8']
# 663/['level4' 'level6']
# 664/['level4' 'level6']
# 665/['level4' 'level6']
# 666/['phone_realEstate' 'level4' 'level6']
# 667/['level4' 'level6']
# 668/['level4' 'level6']
# 669/['level6' 'level8']
# 670/['level6' 'level7' 'level8']
# 671/['level6' 'level8']
# 672/['level4' 'level6']
# 673/['level4' 'level6']
# 674/['level6' 'level7' 'level8']
# 675/['level4' 'level6']
# 676/['level6' 'level8']
# 677/['level4' 'level6']
# 678/['level4' 'level6']
# 679/['level6' 'level8']
# 680/['level4' 'level6']
# 681/['level4' 'level6']
# 682/['phone_realEstate' 'level4' 'level6']
# 683/['level6' 'level8']
# 684/['level6' 'level8']
# 685/['level4' 'level6']
# 686/['level4' 'level6']
# 687/['level4' 'level6']
# 688/['level4' 'level6']
# 689/['level4' 'level6']
# 690/['description' 'level6' 'level8']
# 691/['level4' 'level6']
# 692/['level4' 'level6']
# 693/['phone_realEstate' 'description' 'level6' 'level7' 'level8']
# 694/['level8']
# 695/['rooms' 'level4' 'level6']
# 696/['level4' 'level6']
# 697/['level4' 'level6']
# 698/['level4' 'level6']
# 699/['level6' 'level8']
# 700/['level4' 'level6']
# 701/['level4' 'level6']
# 702/['level6' 'level8']
# 703/['level6' 'level8']
# 704/['level4' 'level6']
# 705/['level6' 'level7' 'level8']
# 706/['level6' 'level8']
# 707/['level6' 'level8']
# 708/['level6' 'level8']
# 709/['level4' 'level6']
# 710/['level4' 'level6']
# 711/['level6' 'level8']
# 712/['level4' 'level6']
# 713/['level4' 'level6']
# 714/['level6' 'level7' 'level8']
# 715/['level4' 'level6']
# 716/['level6' 'level8']
# 717/['level6' 'level8']
# 718/['level6' 'level8']
# 719/['level4' 'level6']
# 720/['level4' 'level6']
# 721/['level4' 'level6']
# 722/['level6' 'level8']
# 723/['level4' 'level6']
# 724/['level6' 'level8']
# 725/['level4' 'level6']
# 726/['level6' 'level8']
# 727/['level6' 'level8']
# 728/['level4' 'level6']
# 729/['level4' 'level6']
# 730/['level6' 'level8']
# 731/['level6' 'level8']
# 732/['level4' 'level6']
# 733/['level6' 'level8']
# 734/['level4' 'level6']
# 735/['level6' 'level8']
# 736/['level4' 'level6']
# 737/['phone_realEstate' 'level4' 'level6']
# 738/['level4' 'level6']
# 739/['level6' 'level7' 'level8']
# 740/['level8']
# 741/['level6' 'level7' 'level8']
# 742/['level4' 'level6']
# 743/['level4' 'level6']
# 744/['level6' 'level8']
# 745/['level4' 'level6']
# 746/['level6' 'level7' 'level8']
# 747/['level6' 'level8']
# 748/['level6' 'level7' 'level8']
# 749/['level4' 'level6']
# 750/['level6' 'level8']
# 751/['level7' 'level8']
# 752/['level4' 'level6']
# 753/['level6' 'level8']
# 754/['level6' 'level8']
# 755/['level6' 'level8']
# 756/['phone_realEstate' 'level4' 'level6']
# 757/['level6' 'level8']
# 758/['level6' 'level7' 'level8']
# 759/['level4' 'level6']
# 760/['level6' 'level8']
# 761/['level6' 'level8']
# 762/['level6' 'level8']
# 763/['level6' 'level8']
# 764/['level6']
# 765/['phone_realEstate' 'level6' 'level8']
# 766/['level6' 'level8']
# 767/['level6' 'level7' 'level8']
# 768/['level6' 'level8']
# 769/['level4' 'level6']
# 770/['level6' 'level8']
# 771/['level7' 'level8']
# 772/['level4' 'level6']
# 773/['level4' 'level6']
# 774/['level6' 'level8']
# 775/['level6' 'level8']
# 776/['level6' 'level8']
# 777/['level6' 'level7' 'level8']
# 778/['level6' 'level8']
# 779/['level6' 'level8']
# 780/['level6' 'level8']
# 781/['level6' 'level7' 'level8']
# 782/['level4' 'level6']
# 783/['level4' 'level6']
# 784/['level4' 'level6']
# 785/['level4' 'level6']
# 786/['level4' 'level6']
# 787/['phone_realEstate' 'level4' 'level6']
# 788/['phone_realEstate' 'bathrooms' 'surface' 'level6' 'level7' 'level8']
# 789/['phone_realEstate' 'bathrooms' 'surface' 'level4' 'level6']
# 790/['level4' 'level6']
# 791/['level4' 'level6']
# 792/['level4' 'level6']
# 793/['level4' 'level6']
# 794/['level4' 'level6']
# 795/['level4' 'level6']
# 796/['phone_realEstate' 'level4' 'level6']
# 797/['phone_realEstate' 'level4' 'level6']
# 798/['phone_realEstate' 'level6' 'level7' 'level8']
# 799/['phone_realEstate' 'level6' 'level7' 'level8']
# 800/['level4' 'level6']
# 801/['level6' 'level8']
# 802/['level4' 'level6']
# 803/['realEstate_name' 'phone_realEstate' 'level4' 'level6']
# 804/['phone_realEstate' 'bathrooms' 'surface' 'level6' 'level8']
# 805/['level4' 'level6']
# 806/['level4' 'level6']
# 807/['level6' 'level8']
# 808/['level4' 'level6']
# 809/['level4' 'level6']
# 810/['level4' 'level6']
# 811/['phone_realEstate' 'description' 'level4' 'level6']
# 812/['level4' 'level6']
# 813/['phone_realEstate' 'level4' 'level6']
# 814/['phone_realEstate' 'level4' 'level6']
# 815/['phone_realEstate' 'level4' 'level6']
# 816/['level6' 'level8']
# 817/['level6' 'level8']
# 818/['level4' 'level6']
# 819/['level4' 'level6']
# 820/['level6' 'level8']
# 821/['phone_realEstate' 'level6' 'level8']
# 822/['level8']
# 823/['phone_realEstate' 'level6' 'level8']
# 824/['level6' 'level8']
# 825/['level4' 'level6']
# 826/['surface' 'level6' 'level8']
# 827/['level6']
# 828/['level6' 'level8']
# 829/['phone_realEstate' 'level4' 'level6']
# 830/['level6' 'level7' 'level8']
# 831/['level6' 'level7' 'level8']
# 832/['level8']
# 833/['level4' 'level6']
# 834/['level6' 'level8']
# 835/['level4' 'level6']
# 836/['surface' 'level6']
# 837/['level6' 'level8']
# 838/['level6' 'level8']
# 839/['level6']
# 840/['rooms' 'level4' 'level6']
# 841/['level6' 'level8']
# 842/['level6' 'level8']
# 843/['level6' 'level8']
# 844/['rooms' 'bathrooms' 'level6' 'level8']
# 845/['bathrooms' 'level6']
# 846/['level6']
# 847/['phone_realEstate' 'level6' 'level8']
# 848/['level4' 'level6']
# 849/['level4' 'level6']
# 850/['level6' 'level8']
# 851/['level4' 'level6']
# 852/['level6' 'level8']
# 853/['level4' 'level6']
# 854/['level6' 'level8']
# 855/['level6' 'level8']
# 856/['level6']
# 857/['level6' 'level8']
# 858/['level6' 'level8']
# 859/['level6' 'level8']
# 860/['level6' 'level8']
# 861/['level6' 'level8']
# 862/['level6' 'level8']
# 863/['level6' 'level8']
# 864/['level6' 'level8']
# 865/['level6' 'level8']
# 866/['level6' 'level8']
# 867/['level6' 'level8']
# 868/['surface' 'level6']
# 869/['level6' 'level8']
# 870/['level6' 'level8']
# 871/['level4' 'level6']
# 872/['level4' 'level6']
# 873/['level6' 'level8']
# 874/['surface' 'level4' 'level6']
# 875/['level6' 'level8']
# 876/['level6' 'level8']
# 877/['level6' 'level8']
# 878/['level6' 'level8']
# 879/['level6' 'level8']
# 880/['level6' 'level8']
# 881/['level6' 'level8']
# 882/['level6' 'level8']
# 883/['level6' 'level8']
# 884/['level6' 'level8']
# 885/['level6' 'level8']
# 886/['level6' 'level8']
# 887/['level6' 'level8']
# 888/['level6' 'level8']
# 889/['level6' 'level8']
# 890/['level6' 'level8']
# 891/['surface' 'level4' 'level6']
# 892/['phone_realEstate' 'level4' 'level6']
# 893/['phone_realEstate' 'level6' 'level7' 'level8']
# 894/['phone_realEstate' 'level4' 'level6']
# 895/['phone_realEstate' 'level4' 'level6']
# 896/['level6' 'level8']
# 897/['level6' 'level8']
# 898/['level6' 'level8']
# 899/['level6' 'level8']
# 900/['level6' 'level8']
# 901/['level7' 'level8']
# 902/['level7' 'level8']
# 903/['level4' 'level6']
# 904/['level4' 'level6']
# 905/['level4' 'level6']
# 906/['level6' 'level8']
# 907/['level6' 'level8']
# 908/['level4' 'level6']
# 909/['level6' 'level8']
# 910/['level7' 'level8']
# 911/['level6' 'level7' 'level8']
# 912/['level6' 'level8']
# 913/['level7' 'level8']
# 914/['level7' 'level8']
# 915/['level7' 'level8']
# 916/['level7' 'level8']
# 917/['level7' 'level8']
# 918/['level7' 'level8']
# 919/['level6' 'level7' 'level8']
# 920/['level6' 'level7' 'level8']
# 921/['level6' 'level7' 'level8']
# 922/['level7' 'level8']
# 923/['level4' 'level6']
# 924/['level4' 'level6']
# 925/['level6' 'level7' 'level8']
# 926/['level4' 'level6']
# 927/['level4' 'level6']
# 928/['level6' 'level8']
# 929/['level6' 'level7' 'level8']
# 930/['level6' 'level7' 'level8']
# 931/['level6' 'level8']
# 932/['surface' 'level4' 'level6']
# 933/['level4' 'level6']
# 934/['surface' 'level4' 'level6']
# 935/['level6' 'level8']
# 936/['level6' 'level7' 'level8']
# 937/['level6' 'level8']
# 938/['level6' 'level8']
# 939/['level6' 'level8']
# 940/['level6' 'level8']
# 941/['level6' 'level8']
# 942/['level4' 'level6']
# 943/['surface' 'level6' 'level8']
# 944/['level6' 'level8']
# 945/['level6' 'level8']
# 946/['level4' 'level6']
# 947/['level6' 'level8']
# 948/['level6']
# 949/['level4' 'level6']
# 950/['level6' 'level8']
# 951/['level4' 'level6']
# 952/['level4' 'level6']
# 953/['level4' 'level6']
# 954/['level4' 'level6']
# 955/['level4' 'level6']
# 956/['level4' 'level6']
# 957/['phone_realEstate' 'level6' 'level8']
# 958/['phone_realEstate' 'level6' 'level7' 'level8']
# 959/['level4' 'level6']
# 960/['level6' 'level8']
# 961/['level6' 'level8']
# 962/['level6' 'level8']
# 963/['level6' 'level8']
# 964/['surface' 'level6' 'level8']
# 965/['level6' 'level8']
# 966/['level6' 'level7' 'level8']
# 967/['level6' 'level8']
# 968/['level6' 'level8']
# 969/['level6' 'level8']
# 970/['level6' 'level8']
# 971/['level6' 'level8']
# 972/['level4' 'level6']
# 973/['surface' 'level6' 'level8']
# 974/['level6' 'level8']
# 975/['level6' 'level8']
# 976/['level4' 'level6']
# 977/['level6' 'level8']
# 978/['level6']
# 979/['level4' 'level6']
# 980/['level6' 'level8']
# 981/['level4' 'level6']
# 982/['level4' 'level6']
# 983/['level4' 'level6']
# 984/['level4' 'level6']
# 985/['level4' 'level6']
# 986/['level4' 'level6']
# 987/['phone_realEstate' 'level6' 'level8']
# 988/['phone_realEstate' 'level6' 'level7' 'level8']
# 989/['level4' 'level6']
# 990/['level6' 'level8']
# 991/['level6' 'level8']
# 992/['level6' 'level8']
# 993/['level6' 'level8']
# 994/['surface' 'level6' 'level8']
# 995/['level4' 'level6']
# 996/['surface' 'level4' 'level6']
# 997/['level6' 'level7' 'level8']
# 998/['level6' 'level7' 'level8']
# 999/['level6' 'level8']
# 1000/['level6' 'level8']
# 1001/['phone_realEstate' 'level7' 'level8']
# 1002/['level6' 'level7' 'level8']
# 1003/['level6' 'level8']
# 1004/['level6' 'level8']
# 1005/['level8']
# 1006/['level7' 'level8']
# 1007/['level7' 'level8']
# 1008/['level6' 'level7' 'level8']
# 1009/['level6' 'level7' 'level8']
# 1010/['level8']
# 1011/['level6' 'level7' 'level8']
# 1012/['level7' 'level8']
# 1013/['level8']
# 1014/['level8']
# 1015/['level6' 'level7' 'level8']
# 1016/['level4' 'level6']
# 1017/['level4' 'level6']
# 1018/['level4' 'level6']
# 1019/['level4' 'level6']
# 1020/['level4' 'level6']
# 1021/['level4' 'level6']
# 1022/['level4' 'level6']
# 1023/['level4' 'level6']
# 1024/['level4' 'level6']
# 1025/['level4' 'level6']
# 1026/['level4' 'level6']
# 1027/['level4' 'level6']
# 1028/['level4' 'level6']
# 1029/['level4' 'level6']
# 1030/['level4' 'level6']
# 1031/['level4' 'level6']
# 1032/['level4' 'level6']
# 1033/['phone_realEstate' 'level4' 'level6']
# 1034/['level4' 'level6']
# 1035/['level4' 'level6']
# 1036/['level6' 'level8']
# 1037/['level6' 'level8']
# 1038/['level6' 'level8']
# 1039/['level6' 'level8']
# 1040/['level6' 'level8']
# 1041/['level6' 'level8']
# 1042/['level6' 'level8']
# 1043/['level6' 'level8']
# 1044/['level6' 'level8']
# 1045/['level6' 'level8']
# 1046/['level6' 'level7' 'level8']
# 1047/['level7' 'level8']
# 1048/['level6' 'level8']
# 1049/['level6' 'level8']
# 1050/['level6' 'level8']
# 1051/['level4' 'level6']
# 1052/['level4' 'level6']
# 1053/['phone_realEstate' 'level6' 'level8']
# 1054/['phone_realEstate' 'level6' 'level7' 'level8']
# 1055/['level6' 'level8']
# 1056/['level6' 'level8']
# 1057/['level6' 'level8']
# 1058/['level6' 'level8']
# 1059/['phone_realEstate' 'level4' 'level6']
# 1060/['level6' 'level7' 'level8']
# 1061/['level4' 'level6']
# 1062/['level6' 'level8']
# 1063/['level6' 'level8']
# 1064/['level6' 'level8']
# 1065/['level4' 'level6']
# 1066/['level4' 'level6']
# 1067/['level6' 'level7' 'level8']
# 1068/['level7' 'level8']
# 1069/['level7' 'level8']
# 1070/['level7' 'level8']
# 1071/['level6' 'level8']
# 1072/['level6' 'level7' 'level8']
# 1073/['level6' 'level8']
# 1074/['level6' 'level8']
# 1075/['level4' 'level6']
# 1076/['level6' 'level7' 'level8']
# 1077/['level6' 'level8']
# 1078/['level6' 'level7' 'level8']
# 1079/['level6' 'level8']
# 1080/['level6' 'level8']
# 1081/['level6' 'level7' 'level8']
# 1082/['level6' 'level7' 'level8']
# 1083/['level6' 'level7' 'level8']
# 1084/['level6' 'level7' 'level8']
# 1085/['level6' 'level7' 'level8']
# 1086/['phone_realEstate' 'description' 'level4' 'level6']
# 1087/['phone_realEstate' 'level4' 'level6']
# 1088/['phone_realEstate' 'level4' 'level6']
# 1089/['level6' 'level7' 'level8']
# 1090/['phone_realEstate' 'level4' 'level6']
# 1091/['phone_realEstate' 'level4' 'level6']
# 1092/['phone_realEstate' 'level4' 'level6']
# 1093/['phone_realEstate' 'level4' 'level6']
# 1094/['phone_realEstate' 'level4' 'level6']
# 1095/['phone_realEstate' 'description' 'level4' 'level6']
# 1096/['phone_realEstate' 'level4' 'level6']
# 1097/['phone_realEstate' 'description' 'level4' 'level6']
# 1098/['level6' 'level7' 'level8']
# 1099/['level6' 'level8']
# 1100/['level6' 'level7' 'level8']
# 1101/['level6' 'level7' 'level8']
# 1102/['level6' 'level7' 'level8']
# 1103/['level4' 'level6']
# 1104/['level4' 'level6']
# 1105/['level4' 'level6']
# 1106/['level4' 'level6']
# 1107/['level4' 'level6']
# 1108/['level4' 'level6']
# 1109/['level6' 'level7' 'level8']
# 1110/['level4' 'level6']
# 1111/['rooms' 'level4' 'level6']
# 1112/['level4' 'level6']
# 1113/['level4' 'level6']
# 1114/['level4' 'level6']
# 1115/['level4' 'level6']
# 1116/['level4' 'level6']
# 1117/['level4' 'level6']
# 1118/['level4' 'level6']
# 1119/['level4' 'level6']
# 1120/['level4' 'level6']
# 1121/['level4' 'level6']
# 1122/['level4' 'level6']
# 1123/['level4' 'level6']
# 1124/['level4' 'level6']
# 1125/['level4' 'level6']
# 1126/['level4' 'level6']
# 1127/['level4' 'level6']
# 1128/['level4' 'level6']
# 1129/['level4' 'level6']
# 1130/['level4' 'level6']
# 1131/['level4' 'level6']
# 1132/['level4' 'level6']
# 1133/['level4' 'level6']
# 1134/['surface' 'level6' 'level8']
# 1135/['level6' 'level8']
# 1136/['level4' 'level6']
# 1137/['surface' 'level4' 'level6']
# 1138/['level4' 'level6']
# 1139/['level6' 'level8']
# 1140/['level6' 'level8']
# 1141/['level6' 'level8']
# 1142/['level6' 'level8']
# 1143/['level4' 'level6']
# 1144/['level6' 'level8']
# 1145/['level6' 'level8']
# 1146/['level4' 'level6']
# 1147/['description' 'level4' 'level6']
# 1148/['level4' 'level6']
# 1149/['level4' 'level6']
# 1150/['level4' 'level6']
# 1151/['level4' 'level6']
# 1152/['level6' 'level8']
# 1153/['level4' 'level6']
# 1154/['level6' 'level8']
# 1155/['phone_realEstate' 'bathrooms' 'surface' 'level6' 'level8']
# 1156/['surface' 'level6' 'level8']
# 1157/['description' 'level6' 'level7' 'level8']
# 1158/['level6' 'level7' 'level8']
# 1159/['level6' 'level7' 'level8']
# 1160/['level6' 'level7' 'level8']
# 1161/['surface' 'level6' 'level7' 'level8']
# 1162/['level6' 'level8']
# 1163/['surface' 'level4' 'level6']
# 1164/['level4' 'level6']
# 1165/['surface' 'level6' 'level7' 'level8']
# 1166/['surface' 'level6' 'level7' 'level8']
# 1167/['surface' 'level4' 'level6']
# 1168/['level6' 'level8']
# 1169/['level4' 'level6']
# 1170/['level4' 'level6']
# 1171/['level4' 'level6']
# 1172/['surface' 'level6' 'level7' 'level8']
# 1173/['level4' 'level6']
# 1174/['surface' 'level4' 'level6']
# 1175/['surface' 'level6' 'level7' 'level8']
# 1176/['level4' 'level6']
# 1177/['surface' 'level8']
# 1178/['level6' 'level8']
# 1179/['level4' 'level6']
# 1180/['level6' 'level8']
# 1181/['surface' 'level6' 'level7' 'level8']
# 1182/['level6' 'level8']
# 1183/['level4' 'level6']
# 1184/['level6' 'level7' 'level8']
# 1185/['level6' 'level8']
# 1186/['phone_realEstate' 'level4' 'level6']
# 1187/['phone_realEstate' 'level6' 'level8']
# 1188/['phone_realEstate' 'level6' 'level8']
# 1189/['phone_realEstate' 'level4' 'level6']
# 1190/['realEstate_name' 'phone_realEstate' 'level4' 'level6']
# 1191/['phone_realEstate' 'level6' 'level8']
# 1192/['phone_realEstate' 'level4' 'level6']
# 1193/['phone_realEstate' 'level6' 'level8']
# 1194/['phone_realEstate' 'level4' 'level6']
# 1195/['phone_realEstate' 'level6' 'level8']
# 1196/['phone_realEstate' 'level4' 'level6']
# 1197/['level6' 'level8']
# 1198/['level6' 'level8']
# 1199/['level6' 'level8']
# 1200/['level6' 'level8']
# 1201/['level6' 'level8']
# 1202/['level6']
# 1203/['level6' 'level8']
# 1204/['level6']
# 1205/['level6' 'level8']
# 1206/['level4' 'level6']
# 1207/['level4' 'level6']
# 1208/['level6' 'level7' 'level8']
# 1209/['level4' 'level6']
# 1210/['phone_realEstate' 'level6' 'level8']
# 1211/['level4' 'level6']
# 1212/['level6' 'level7' 'level8']
# 1213/['phone_realEstate' 'level4' 'level6']
# 1214/['level6' 'level7' 'level8']
# 1215/['level6' 'level7' 'level8']
# 1216/['phone_realEstate' 'level4' 'level6']
# 1217/['level6' 'level7' 'level8']
# 1218/['level6' 'level7' 'level8']
# 1219/['level4' 'level6']
# 1220/['level6' 'level7' 'level8']
# 1221/['level6' 'level7' 'level8']
# 1222/['level6' 'level7' 'level8']
# 1223/['level6' 'level7' 'level8']
# 1224/['rooms' 'bathrooms' 'level6' 'level8']
# 1225/['level6' 'level8']
# 1226/['level6' 'level8']
# 1227/['level4' 'level6']
# 1228/['level6' 'level7' 'level8']
# 1229/['level6' 'level7' 'level8']
# 1230/['level6' 'level7' 'level8']
# 1231/['level6' 'level7' 'level8']
# 1232/['level6' 'level7' 'level8']
# 1233/['level6' 'level7' 'level8']
# 1234/['level6' 'level7' 'level8']
# 1235/['level6' 'level7' 'level8']
# 1236/['level6' 'level7' 'level8']
# 1237/['level6' 'level7' 'level8']
# 1238/['level6' 'level7' 'level8']
# 1239/['level6' 'level7' 'level8']
# 1240/['level6' 'level7' 'level8']
# 1241/['level6' 'level7' 'level8']
# 1242/['level6' 'level7' 'level8']
# 1243/['level6' 'level7' 'level8']
# 1244/['level4' 'level6']
# 1245/['level4' 'level6']
# 1246/['level4' 'level6']
# 1247/['level4' 'level6']
# 1248/['level4' 'level6']
# 1249/['level4' 'level6']
# 1250/['level4' 'level6']
# 1251/['level4' 'level6']
# 1252/['level4' 'level6']
# 1253/['level4' 'level6']
# 1254/['level4' 'level6']
# 1255/['level4' 'level6']
# 1256/['level4' 'level6']
# 1257/['level4' 'level6']
# 1258/['level4' 'level6']
# 1259/['level4' 'level6']
# 1260/['level4' 'level6']
# 1261/['level6' 'level8']
# 1262/['level4' 'level6']
# 1263/['phone_realEstate' 'surface' 'level4' 'level6']
# 1264/['level4' 'level6']
# 1265/['level4' 'level6']
# 1266/['level6' 'level8']
# 1267/['rooms' 'bathrooms' 'level6' 'level7' 'level8']
# 1268/['level6' 'level8']
# 1269/['level4' 'level6']
# 1270/['level4' 'level6']
# 1271/['level4' 'level6']
# 1272/['level4' 'level6']
# 1273/['level4' 'level6']
# 1274/['level4' 'level6']
# 1275/['level4' 'level6']
# 1276/['level4' 'level6']
# 1277/['level4' 'level6']
# 1278/['level4' 'level6']
# 1279/['level4' 'level6']
# 1280/['level4' 'level6']
# 1281/['level4' 'level6']
# 1282/['level4' 'level6']
# 1283/['level4' 'level6']
# 1284/['level4' 'level6']
# 1285/['level4' 'level6']
# 1286/['level4' 'level6']
# 1287/['level4' 'level6']
# 1288/['level7' 'level8']
# 1289/['level7' 'level8']
# 1290/['level7' 'level8']
# 1291/['level4' 'level6']
# 1292/['level4' 'level6']
# 1293/['level8']
# 1294/['level4' 'level6']
# 1295/['level4' 'level6']
# 1296/['level4' 'level6']
# 1297/['level4' 'level6']
# 1298/['level4' 'level6']
# 1299/['level4' 'level6']
# 1300/['level4' 'level6']
# 1301/['level4' 'level6']
# 1302/['level4' 'level6']
# 1303/['level4' 'level6']
# 1304/['level4' 'level6']
# 1305/['level4' 'level6']
# 1306/['level4' 'level6']
# 1307/['level4' 'level6']
# 1308/['level4' 'level6']
# 1309/['level4' 'level6']
# 1310/['level4' 'level6']
# 1311/['level4' 'level6']
# 1312/['level4' 'level6']
# 1313/['level4' 'level6']
# 1314/['level4' 'level6']
# 1315/['level4' 'level6']
# 1316/['level4' 'level6']
# 1317/['level4' 'level6']
# 1318/['level4' 'level6']
# 1319/['level4' 'level6']
# 1320/['level4' 'level6']
# 1321/['level4' 'level6']
# 1322/['level4' 'level6']
# 1323/['level4' 'level6']
# 1324/['level4' 'level6']
# 1325/['level4' 'level6']
# 1326/['level4' 'level6']
# 1327/['level4' 'level6']
# 1328/['level4' 'level6']
# 1329/['level4' 'level6']
# 1330/['level4' 'level6']
# 1331/['level4' 'level6']
# 1332/['level4' 'level6']
# 1333/['level4' 'level6']
# 1334/['level4' 'level6']
# 1335/['level4' 'level6']
# 1336/['level4' 'level6']
# 1337/['level4' 'level6']
# 1338/['level4' 'level6']
# 1339/['level4' 'level6']
# 1340/['level4' 'level6']
# 1341/['level4' 'level6']
# 1342/['level4' 'level6']
# 1343/['level4' 'level6']
# 1344/['level4' 'level6']
# 1345/['level4' 'level6']
# 1346/['level4' 'level6']
# 1347/['level4' 'level6']
# 1348/['level4' 'level6']
# 1349/['level4' 'level6']
# 1350/['level4' 'level6']
# 1351/['level4' 'level6']
# 1352/['level4' 'level6']
# 1353/['level4' 'level6']
# 1354/['level4' 'level6']
# 1355/['level4' 'level6']
# 1356/['level4' 'level6']
# 1357/['level4' 'level6']
# 1358/['level4' 'level6']
# 1359/['level4' 'level6']
# 1360/['level4' 'level6']
# 1361/['level4' 'level6']
# 1362/['level4' 'level6']
# 1363/['level4' 'level6']
# 1364/['rooms' 'level4' 'level6']
# 1365/['level4' 'level6']
# 1366/['level4' 'level6']
# 1367/['level4' 'level6']
# 1368/['level4' 'level6']
# 1369/['level4' 'level6']
# 1370/['level6' 'level8']
# 1371/['level8']
# 1372/['level6' 'level8']
# 1373/['level4' 'level6']
# 1374/['level6' 'level8']
# 1375/['level6' 'level8']
# 1376/['rooms' 'bathrooms' 'level6' 'level8']
# 1377/['description' 'level4' 'level6']
# 1378/['level6' 'level8']
# 1379/['level6' 'level7' 'level8']
# 1380/['level6' 'level8']
# 1381/['level6' 'level8']
# 1382/['level6' 'level8']
# 1383/['level6' 'level8']
# 1384/['level6' 'level8']
# 1385/['level4' 'level6']
# 1386/['level6' 'level8']
# 1387/['level6' 'level8']
# 1388/['level6' 'level8']
# 1389/['level4' 'level6']
# 1390/['level4' 'level6']
# 1391/['level4' 'level6']
# 1392/['level8']
# 1393/['level6' 'level8']
# 1394/['level6' 'level8']
# 1395/['level6' 'level8']
# 1396/['level6' 'level8']
# 1397/['level6' 'level8']
# 1398/['level4' 'level6']
# 1399/['level6' 'level8']
# 1400/['level6' 'level8']
# 1401/['level6' 'level8']
# 1402/['level6' 'level8']
# 1403/['level6' 'level8']
# 1404/['level4' 'level6']
# 1405/['level4' 'level6']
# 1406/['level4' 'level6']
# 1407/['level4' 'level6']
# 1408/['level4' 'level6']
# 1409/['level4' 'level6']
# 1410/['level4' 'level6']
# 1411/['level4' 'level6']
# 1412/['level4' 'level6']
# 1413/['level8']
# 1414/['phone_realEstate' 'level4' 'level6']
# 1415/['phone_realEstate' 'level4' 'level6']
# 1416/['phone_realEstate' 'level4' 'level6']
# 1417/['phone_realEstate' 'level4' 'level6']
# 1418/['phone_realEstate' 'level4' 'level6']
# 1419/['phone_realEstate' 'level4' 'level6']
# 1420/['phone_realEstate' 'level4' 'level6']
# 1421/['bathrooms' 'level4' 'level6']
# 1422/['phone_realEstate' 'level4' 'level6']
# 1423/['level4' 'level6']
# 1424/['level4' 'level6']
# 1425/['surface' 'level6' 'level8']
# 1426/['level4' 'level6']
# 1427/['level4' 'level6']
# 1428/['level4' 'level6']
# 1429/['level4' 'level6']
# 1430/['level4' 'level6']
# 1431/['level4' 'level6']
# 1432/['level4' 'level6']
# 1433/['level4' 'level6']
# 1434/['level4' 'level6']
# 1435/['level4' 'level6']
# 1436/['level6' 'level8']
# 1437/['level4' 'level6']
# 1438/['level6' 'level8']
# 1439/['level6' 'level8']
# 1440/['level4' 'level6']
# 1441/['level8']
# 1442/['level4' 'level6']
# 1443/['level6' 'level7' 'level8']
# 1444/['level6' 'level8']
# 1445/['level8']
# 1446/['level6' 'level7' 'level8']
# 1447/['level7' 'level8']
# 1448/['level6' 'level8']
# 1449/['level6' 'level8']
# 1450/['level6' 'level8']
# 1451/['level6' 'level8']
# 1452/['level7' 'level8']
# 1453/['level6' 'level8']
# 1454/['level4' 'level6']
# 1455/['level6' 'level8']
# 1456/['level6' 'level8']
# 1457/['level7' 'level8']
# 1458/['description' 'level6' 'level8']
# 1459/['level6' 'level8']
# 1460/['level6' 'level8']
# 1461/['level6' 'level7' 'level8']
# 1462/['level4' 'level6']
# 1463/['level4' 'level6']
# 1464/['rooms' 'level4' 'level6']
# 1465/['bathrooms' 'level4' 'level6']
# 1466/['phone_realEstate' 'level6' 'level8']
# 1467/['level6' 'level8']
# 1468/['phone_realEstate' 'level6' 'level8']
# 1469/['level6' 'level8']
# 1470/['level4' 'level6']
# 1471/['level4' 'level6']
# 1472/['rooms' 'bathrooms' 'level6' 'level8']
# 1473/['level6' 'level8']
# 1474/['level6' 'level7' 'level8']
# 1475/['level4' 'level6']
# 1476/['level6' 'level8']
# 1477/['level4' 'level6']
# 1478/['level4' 'level6']
# 1479/['phone_realEstate' 'level4' 'level6']
# 1480/['level6' 'level8']
# 1481/['rooms' 'bathrooms' 'level7' 'level8']
# 1482/['level6' 'level8']
# 1483/['level4' 'level6']
# 1484/['level4' 'level6']
# 1485/['level4' 'level6']
# 1486/['level4' 'level6']
# 1487/['level6' 'level8']
# 1488/['level4' 'level6']
# 1489/['level6' 'level8']
# 1490/['level4' 'level6']
# 1491/['phone_realEstate' 'level6' 'level8']
# 1492/['level8']
# 1493/['level8']
# 1494/['rooms' 'bathrooms' 'level4' 'level6']
# 1495/['bathrooms' 'level4' 'level6']
# 1496/['level4' 'level6']
# 1497/['level4' 'level6']
# 1498/['level4' 'level6']
# 1499/['level4' 'level6']
# 1500/['level6' 'level8']
# 1501/['level6' 'level8']
# 1502/['level6' 'level8']
# 1503/['level8']
# 1504/['level4' 'level6']
# 1505/['level4' 'level6']
# 1506/['phone_realEstate' 'level4' 'level6']
# 1507/['phone_realEstate' 'level6' 'level7' 'level8']
# 1508/['level6' 'level7' 'level8']
# 1509/['level4' 'level6']
# 1510/['level4' 'level6']
# 1511/['level8']
# 1512/['level4' 'level6']
# 1513/['level6' 'level8']
# 1514/['level4' 'level6']
# 1515/['level6' 'level8']
# 1516/['level6' 'level8']
# 1517/['level7' 'level8']
# 1518/['level6' 'level8']
# 1519/['level6' 'level8']
# 1520/['level4' 'level6']
# 1521/['level4' 'level6']
# 1522/['level4' 'level6']
# 1523/['phone_realEstate' 'level6' 'level8']
# 1524/['level6' 'level7' 'level8']
# 1525/['level6' 'level8']
# 1526/['level6' 'level8']
# 1527/['phone_realEstate' 'level6' 'level8']
# 1528/['level6' 'level7' 'level8']
# 1529/['level6' 'level7' 'level8']
# 1530/['level6' 'level8']
# 1531/['level4' 'level6']
# 1532/['phone_realEstate' 'level4' 'level6']
# 1533/['level6' 'level7' 'level8']
# 1534/['level6' 'level7' 'level8']
# 1535/['level4' 'level6']
# 1536/['surface' 'level6' 'level8']
# 1537/['level6']
# 1538/['phone_realEstate' 'level6' 'level8']
# 1539/['level4' 'level6']
# 1540/['level4' 'level6']
# 1541/['level4' 'level6']
# 1542/['level6' 'level8']
# 1543/['level6' 'level8']
# 1544/['level4' 'level6']
# 1545/['level6' 'level8']
# 1546/['level6' 'level8']
# 1547/['level6' 'level7' 'level8']
# 1548/['level6' 'level8']
# 1549/['level6' 'level8']
# 1550/['level6' 'level8']
# 1551/['level6' 'level7' 'level8']
# 1552/['level8']
# 1553/['level6' 'level8']
# 1554/['level6' 'level8']
# 1555/['level4' 'level6']
# 1556/['rooms' 'level4' 'level6']
# 1557/['level6' 'level8']
# 1558/['level6' 'level8']
# 1559/['level6' 'level8']
# 1560/['level6' 'level8']
# 1561/['level6' 'level8']
# 1562/['level6' 'level7' 'level8']
# 1563/['level6' 'level7' 'level8']
# 1564/['phone_realEstate' 'level4' 'level6']
# 1565/['level4' 'level6']
# 1566/['level4' 'level6']
# 1567/['level6' 'level8']
# 1568/['level6' 'level8']
# 1569/['level6' 'level8']
# 1570/['level4' 'level6']
# 1571/['level6' 'level8']
# 1572/['level4' 'level6']
# 1573/['rooms' 'level4' 'level6']
# 1574/['level4' 'level6']
# 1575/['level4' 'level6']
# 1576/['bathrooms' 'level6' 'level8']
# 1577/['level4' 'level6']
# 1578/['level6' 'level8']
# 1579/['level4' 'level6']
# 1580/['level6' 'level7' 'level8']
# 1581/['level4' 'level6']
# 1582/['level6' 'level8']
# 1583/['level4' 'level6']
# 1584/['level6' 'level8']
# 1585/['level6' 'level7' 'level8']
# 1586/['level6' 'level8']
# 1587/['level6' 'level8']
# 1588/['level6' 'level8']
# 1589/['level6' 'level7' 'level8']
# 1590/['level6' 'level8']
# 1591/['level6' 'level8']
# 1592/['level4' 'level6']
# 1593/['level6' 'level7' 'level8']
# 1594/['level6' 'level8']
# 1595/['level6' 'level7' 'level8']
# 1596/['level4' 'level6']
# 1597/['level8']
# 1598/['bathrooms' 'level4' 'level6']
# 1599/['level4' 'level6']
# 1600/['level6' 'level8']
# 1601/['level4' 'level6']
# 1602/['level6' 'level8']
# 1603/['level6' 'level7' 'level8']
# 1604/['level4' 'level6']
# 1605/['level6' 'level8']
# 1606/['level4' 'level6']
# 1607/['level6' 'level8']
# 1608/['level6' 'level8']
# 1609/['level6' 'level8']
# 1610/['level4' 'level6']
# 1611/['level6' 'level8']
# 1612/['level4' 'level6']
# 1613/['level6' 'level8']
# 1614/['level4' 'level6']
# 1615/['level6' 'level8']
# 1616/['level4' 'level6']
# 1617/['level4' 'level6']
# 1618/['level4' 'level6']
# 1619/['rooms' 'level6' 'level8']
# 1620/['level6']
# 1621/['level6']
# 1622/['level6' 'level8']
# 1623/['level6' 'level8']
# 1624/['level4' 'level6']
# 1625/['level6' 'level8']
# 1626/['level4' 'level6']
# 1627/['level4' 'level6']
# 1628/['level6' 'level8']
# 1629/['level6' 'level8']
# 1630/['level4' 'level6']
# 1631/['level6' 'level8']
# 1632/['level6' 'level8']
# 1633/['level6' 'level7' 'level8']
# 1634/['level4' 'level6']
# 1635/['level6' 'level8']
# 1636/['level6' 'level8']
# 1637/['level6']
# 1638/['level6' 'level7' 'level8']
# 1639/['rooms' 'level4' 'level6']
# 1640/['level6' 'level7' 'level8']
# 1641/['level4' 'level6']
# 1642/['level4' 'level6']
# 1643/['level4' 'level6']
# 1644/['bathrooms' 'level4' 'level6']
# 1645/['level6' 'level8']
# 1646/['level6' 'level8']
# 1647/['level6' 'level8']
# 1648/['level6' 'level8']
# 1649/['level6' 'level7' 'level8']
# 1650/['level6' 'level8']
# 1651/['level4' 'level6']
# 1652/['level6' 'level7' 'level8']
# 1653/['level8']
# 1654/['level6' 'level8']
# 1655/['level4' 'level6']
# 1656/['level6' 'level8']
# 1657/['level4' 'level6']
# 1658/['level4' 'level6']
# 1659/['phone_realEstate' 'level6' 'level8']
# 1660/['bathrooms' 'level6' 'level8']
# 1661/['level4' 'level6']
# 1662/['level4' 'level6']
# 1663/['level4' 'level6']
# 1664/['level6' 'level7' 'level8']
# 1665/['level4' 'level6']
# 1666/['phone_realEstate' 'level6' 'level8']
# 1667/['level4' 'level6']
# 1668/['level6' 'level8']
# 1669/['level6' 'level8']
# 1670/['level6' 'level8']
# 1671/['level4' 'level6']
# 1672/['level6' 'level7' 'level8']
# 1673/['level6' 'level8']
# 1674/['level6' 'level8']
# 1675/['level6' 'level7' 'level8']
# 1676/['level6' 'level8']
# 1677/['level6' 'level8']
# 1678/['level4' 'level6']
# 1679/['level6' 'level8']
# 1680/['level4' 'level6']
# 1681/['level4' 'level6']
# 1682/['level4' 'level6']
# 1683/['level6' 'level8']
# 1684/['level6' 'level8']
# 1685/['level4' 'level6']
# 1686/['level4' 'level6']
# 1687/['level6' 'level8']
# 1688/['level4' 'level6']
# 1689/['level6' 'level8']
# 1690/['level6' 'level7' 'level8']
# 1691/['level6' 'level8']
# 1692/['level6' 'level8']
# 1693/['level6' 'level8']
# 1694/['level4' 'level6']
# 1695/['level6' 'level8']
# 1696/['level6' 'level8']
# 1697/['level6' 'level8']
# 1698/['level6' 'level8']
# 1699/['phone_realEstate' 'level6' 'level7' 'level8']
# 1700/['level6' 'level8']
# 1701/['level4' 'level6']
# 1702/['bathrooms' 'level4' 'level6' 'level8']
# 1703/['level7' 'level8']
# 1704/['level6' 'level8']
# 1705/['level6' 'level8']
# 1706/['level4' 'level6']
# 1707/['level8']
# 1708/['level6' 'level8']
# 1709/['level4' 'level6']
# 1710/['level4' 'level6']
# 1711/['level7' 'level8']
# 1712/['level4' 'level6']
# 1713/['level6' 'level7' 'level8']
# 1714/['level6' 'level8']
# 1715/['level4' 'level6']
# 1716/['level4' 'level6']
# 1717/['level6' 'level8']
# 1718/['level4' 'level6']
# 1719/['level6' 'level8']
# 1720/['level6' 'level7' 'level8']
# 1721/['level6' 'level8']
# 1722/['level6' 'level8']
# 1723/['level6' 'level8']
# 1724/['level4' 'level6']
# 1725/['level6' 'level8']
# 1726/['level6' 'level8']
# 1727/['level6' 'level8']
# 1728/['level6' 'level8']
# 1729/['phone_realEstate' 'level6' 'level7' 'level8']
# 1730/['level6' 'level8']
# 1731/['level4' 'level6']
# 1732/['bathrooms' 'level4' 'level6' 'level8']
# 1733/['level7' 'level8']
# 1734/['level6' 'level8']
# 1735/['level6' 'level8']
# 1736/['level4' 'level6']
# 1737/['level8']
# 1738/['level6' 'level8']
# 1739/['level4' 'level6']
# 1740/['level4' 'level6']
# 1741/['level7' 'level8']
# 1742/['level4' 'level6']
# 1743/['level6' 'level7' 'level8']
# 1744/['level6' 'level8']
# 1745/['level6' 'level8']
# 1746/['level4' 'level6']
# 1747/['level6' 'level8']
# 1748/['level4' 'level6']
# 1749/['level6' 'level8']
# 1750/['level4' 'level6']
# 1751/['level4' 'level6']
# 1752/['level6' 'level8']
# 1753/['bathrooms' 'level4' 'level6']
# 1754/['level6' 'level8']
# 1755/['level4' 'level6']
# 1756/['level4' 'level6']
# 1757/['level6' 'level8']
# 1758/['level6' 'level8']
# 1759/['level8']
# 1760/['level4' 'level6']
# 1761/['bathrooms' 'level4' 'level6']
# 1762/['level4' 'level6']
# 1763/['level4' 'level6']
# 1764/['level4' 'level6']
# 1765/['level4' 'level6']
# 1766/['level4' 'level6']
# 1767/['level4' 'level6']
# 1768/['level4' 'level6']
# 1769/['level6' 'level8']
# 1770/['level6' 'level7' 'level8']
# 1771/['level4' 'level6']
# 1772/['level6' 'level7' 'level8']
# 1773/['level4' 'level6']
# 1774/['level4' 'level6']
# 1775/['level6' 'level8']
# 1776/['level6' 'level7' 'level8']
# 1777/['level6' 'level7' 'level8']
# 1778/['level6' 'level8']
# 1779/['level6' 'level8']
# 1780/['level4' 'level6']
# 1781/['level6' 'level8']
# 1782/['level4' 'level6']
# 1783/['level6' 'level8']
# 1784/['level6' 'level8']
# ...
# 14791/['rooms' 'level4' 'level6']
# 14792/['level4' 'level6']
# 14793/['level4' 'level6']
# 14794/['surface' 'level6' 'level8']
# 14795/['level4' 'level6']
# 14796/['phone_realEstate' 'level6' 'level7' 'level8']
# 14797/['level7' 'level8']
# 14798/['phone_realEstate' 'level4' 'level6']
# 14799/['level8']
# 14800/['level6' 'level8']
# 14801/['level4' 'level6']
# 14802/['level4' 'level6']
# 14803/['level4' 'level6']
# 14804/['level6' 'level8']
# 14805/['level4' 'level6']
# 14806/['level6' 'level7' 'level8']
# 14807/['level6' 'level7' 'level8']
# 14808/['phone_realEstate' 'surface' 'level4' 'level6']
# 14809/['level4' 'level6']
# 14810/['level4' 'level6']
# 14811/['level4' 'level6']
# 14812/['level6' 'level7' 'level8']
# 14813/['level6' 'level7' 'level8']
# 14814/['level6' 'level7' 'level8']
# 14815/['phone_realEstate' 'level4' 'level6']
# 14816/['phone_realEstate' 'level6' 'level7' 'level8']
# 14817/['phone_realEstate' 'level4' 'level6']
# 14818/['phone_realEstate' 'level4' 'level6']
# 14819/['level6' 'level7' 'level8']
# 14820/['phone_realEstate' 'level4' 'level6']
# 14821/['phone_realEstate' 'level4' 'level6']
# 14822/['level6' 'level7' 'level8']
# 14823/['level6' 'level8']
# 14824/['phone_realEstate' 'level4' 'level6']
# 14825/['level6' 'level8']
# 14826/['phone_realEstate' 'level6' 'level8']
# 14827/['level6' 'level7' 'level8']
# 14828/['level8']
# 14829/['level6' 'level7' 'level8']
# 14830/['level4' 'level6']
# 14831/['level4' 'level6']
# 14832/['level6' 'level7' 'level8']
# 14833/['level4' 'level6']
# 14834/['level4' 'level6']
# 14835/['level6' 'level8']
# 14836/['level4' 'level6']
# 14837/['level6' 'level8']
# 14838/['level4' 'level6']
# 14839/['level4' 'level6']
# 14840/['level6' 'level8']
# 14841/['level8']
# 14842/['level6' 'level8']
# 14843/['level4' 'level6']
# 14844/['level4' 'level6']
# 14845/['level6' 'level8']
# 14846/['level6' 'level8']
# 14847/['level4' 'level6']
# 14848/['level6' 'level8']
# 14849/['level4' 'level6']
# 14850/['level6' 'level8']
# 14851/['level4' 'level6']
# 14852/['rooms' 'bathrooms' 'level6' 'level7' 'level8']
# 14853/['level6' 'level8']
# 14854/['level6' 'level8']
# 14855/['level4' 'level6']
# 14856/['level4' 'level6']
# 14857/['level6' 'level8']
# 14858/['level6' 'level8']
# 14859/['level4' 'level6']
# 14860/['level8']
# 14861/['level6' 'level8']
# 14862/['level6' 'level7' 'level8']
# 14863/['level4' 'level6']
# 14864/['level4' 'level6']
# 14865/['level6' 'level8']
# 14866/['level4' 'level6']
# 14867/['level4' 'level6']
# 14868/['surface' 'level4' 'level6']
# 14869/['level6' 'level8']
# 14870/['level6' 'level8']
# 14871/['level6' 'level8']
# 14872/['level4' 'level6']
# 14873/['level4' 'level6']
# 14874/['level4' 'level6']
# 14875/['level6' 'level8']
# 14876/['level6' 'level8']
# 14877/['level6' 'level8']
# 14878/['level6' 'level8']
# 14879/['level4' 'level6']
# 14880/['level6' 'level8']
# 14881/['level6' 'level8']
# 14882/['level4' 'level6']
# 14883/['level4' 'level6']
# 14884/['level4' 'level6']
# 14885/['level4' 'level6']
# 14886/['level4' 'level6']
# 14887/['level6' 'level8']
# 14888/['level4' 'level6']
# 14889/['surface' 'level6' 'level8']
# 14890/['level6' 'level7' 'level8']
# 14891/['level6' 'level8']
# 14892/['level4' 'level6']
# 14893/['level6' 'level8']
# 14894/['level4' 'level6']
# 14895/['level4' 'level6']
# 14896/['level6']
# 14897/['level4' 'level6']
# 14898/['level4' 'level6']
# 14899/['level4' 'level6']
# 14900/['level4' 'level6']
# 14901/['level4' 'level6']
# 14902/['level4' 'level6']
# 14903/['level4' 'level6']
# 14904/['level6' 'level8']
# 14905/['level4' 'level6']
# 14906/['level6' 'level8']
# 14907/['surface' 'level6' 'level7' 'level8']
# 14908/['level6' 'level8']
# 14909/['level6' 'level8']
# 14910/['level6' 'level7' 'level8']
# 14911/['surface' 'level6' 'level8']
# 14912/['level6' 'level8']
# 14913/['level6' 'level8']
# 14914/['level6' 'level8']
# 14915/['level6' 'level8']
# 14916/['level6' 'level8']
# 14917/['level8']
# 14918/['level4' 'level6']
# 14919/['level8']
# 14920/['level6' 'level8']
# 14921/['level4' 'level6']
# 14922/['level4' 'level6']
# 14923/['level4' 'level6']
# 14924/['level4' 'level6']
# 14925/['level8']
# 14926/['level4' 'level6']
# 14927/['level4' 'level6']
# 14928/['level6' 'level8']
# 14929/['level8']
# 14930/['level4' 'level6']
# 14931/['rooms' 'level4' 'level6']
# 14932/['level8']
# 14933/['level4' 'level6']
# 14934/['level6' 'level8']
# 14935/['level4' 'level6']
# 14936/['level4' 'level6']
# 14937/['level8']
# 14938/['level4' 'level6']
# 14939/['level8']
# 14940/['surface' 'level6' 'level8']
# 14941/['level4' 'level6']
# 14942/['level4' 'level6']
# 14943/['phone_realEstate' 'level4' 'level6']
# 14944/['phone_realEstate' 'level6' 'level8']
# 14945/['level4' 'level6']
# 14946/['level6' 'level8']
# 14947/['level6' 'level7' 'level8']
# 14948/['level6' 'level7' 'level8']
# 14949/['level6' 'level8']
# 14950/['level6' 'level8']
# 14951/['level4' 'level6']
# 14952/['level7' 'level8']
# 14953/['phone_realEstate' 'level7' 'level8']
# 14954/['level4' 'level6']
# 14955/['level6' 'level7' 'level8']
# 14956/['level6' 'level8']
# 14957/['level4' 'level6']
# 14958/['level4' 'level6']
# 14959/['level4' 'level6']
# 14960/['level4' 'level6']
# 14961/['level4' 'level6']
# 14962/['level4' 'level6']
# 14963/['level4' 'level6']
# 14964/['level6' 'level8']
# 14965/['level4' 'level6']
# 14966/['level6' 'level8']
# 14967/['level6' 'level8']
# 14968/['level6' 'level8']
# 14969/['level6']
# 14970/['level6' 'level8']
# 14971/['level6' 'level8']
# 14972/['level6' 'level8']
# 14973/['level4' 'level6']
# 14974/['level6' 'level7' 'level8']
# 14975/['level4' 'level6']
# 14976/['level4' 'level6']
# 14977/['level4' 'level6']
# 14978/['level4' 'level6']
# 14979/['surface' 'level6' 'level8']
# 14980/['level4' 'level6']
# 14981/['level4' 'level6']
# 14982/['level6' 'level8']
# 14983/['level4' 'level6']
# 14984/['level7' 'level8']
# 14985/['level6' 'level7' 'level8']
# 14986/['level6' 'level8']
# 14987/['level6' 'level8']
# 14988/['level4' 'level6']
# 14989/['level4' 'level6']
# 14990/['level6' 'level7' 'level8']
# 14991/['level6' 'level8']
# 14992/['level6' 'level8']
# 14993/['level6' 'level8']
# 14994/['level4' 'level6']
# 14995/['level4' 'level6']
# 14996/['level6' 'level7' 'level8']
# 14997/['level4' 'level6']
# 14998/['level6' 'level7' 'level8']
# 14999/['phone_realEstate' 'level6' 'level8']
# 15000/['level4' 'level6']
# 15001/['level6' 'level7' 'level8']
# 15002/['level6' 'level8']
# 15003/['level7' 'level8']
# 15004/['level4' 'level6']
# 15005/['bathrooms' 'level4' 'level6' 'level8']
# 15006/['level6' 'level7' 'level8']
# 15007/['level6' 'level8']
# 15008/['level4' 'level6']
# 15009/['level6' 'level7' 'level8']
# 15010/['level6' 'level8']
# 15011/['level6' 'level8']
# 15012/['level6' 'level8']
# 15013/['level6' 'level7' 'level8']
# 15014/['level6' 'level8']
# 15015/['level6' 'level8']
# 15016/['level6' 'level8']
# 15017/['level6' 'level8']
# 15018/['level6' 'level8']
# 15019/['level6' 'level8']
# 15020/['level6' 'level7' 'level8']
# 15021/['rooms' 'level4' 'level6']
# 15022/['level4' 'level6']
# 15023/['level6' 'level8']
# 15024/['level6' 'level8']
# 15025/['level4' 'level6']
# 15026/['level6' 'level8']
# 15027/['level4' 'level6']
# 15028/['level6' 'level8']
# 15029/['level4' 'level6']
# 15030/['level8']
# 15031/['level4' 'level6']
# 15032/['level7' 'level8']
# 15033/['level6' 'level8']
# 15034/['level6' 'level8']
# 15035/['level6' 'level7' 'level8']
# 15036/['level6' 'level7' 'level8']
# 15037/['level6' 'level7' 'level8']
# 15038/['level6' 'level7' 'level8']
# 15039/['level4' 'level6']
# 15040/['level4' 'level6']
# 15041/['level4' 'level6']
# 15042/['level4' 'level6']
# 15043/['level6' 'level7' 'level8']
# 15044/['level6' 'level8']
# 15045/['level6' 'level8']
# 15046/['level4' 'level6']
# 15047/['level4' 'level6']
# 15048/['surface' 'level6' 'level7' 'level8']
# 15049/['level4' 'level6']
# 15050/['level6' 'level8']
# 15051/['rooms' 'bathrooms' 'level6' 'level8']
# 15052/['level4' 'level6']
# 15053/['level6' 'level8']
# 15054/['phone_realEstate' 'level6' 'level8']
# 15055/['level4' 'level6']
# 15056/['level4' 'level6']
# 15057/['level6' 'level7' 'level8']
# 15058/['level4' 'level6']
# 15059/['level6' 'level8']
# 15060/['phone_realEstate' 'level4' 'level6']
# 15061/['level4' 'level6']
# 15062/['phone_realEstate' 'bathrooms' 'surface' 'level6' 'level8']
# 15063/['level6' 'level8']
# 15064/['surface' 'level6' 'level8']
# 15065/['surface' 'level6' 'level7' 'level8']
# 15066/['level6' 'level7' 'level8']
# 15067/['phone_realEstate' 'level6' 'level7' 'level8']
# 15068/['level6' 'level8']
# 15069/['level4' 'level6']
# 15070/['level4' 'level6']
# 15071/['level4' 'level6']
# 15072/['level7' 'level8']
# 15073/['surface' 'level4' 'level6']
# 15074/['level6' 'level7' 'level8']
# 15075/['level6' 'level7' 'level8']
# 15076/['level4' 'level6']
# 15077/['level6' 'level8']
# 15078/['level4' 'level6']
# 15079/['surface' 'level4' 'level6']
# 15080/['level6' 'level8']
# 15081/['phone_realEstate' 'level6' 'level7' 'level8']
# 15082/['level4' 'level6']
# 15083/['level4' 'level6']
# 15084/['level6' 'level8']
# 15085/['description' 'level6' 'level7' 'level8']
# 15086/['level6' 'level8']
# 15087/['level6' 'level8']
# 15088/['level6' 'level7' 'level8']
# 15089/['level6' 'level8']
# 15090/['level4' 'level6']
# 15091/['level6' 'level8']
# 15092/['level6' 'level8']
# 15093/['description' 'level4' 'level6']
# 15094/['level6' 'level8']
# 15095/['level6' 'level8']
# 15096/['bathrooms' 'level4' 'level6' 'level8']
# 15097/['level4' 'level6']
# 15098/['phone_realEstate' 'level4' 'level6']
# 15099/['level6' 'level7' 'level8']
# 15100/['level6' 'level8']
# 15101/['level6' 'level7' 'level8']
# 15102/['level6' 'level8']
# 15103/['level4' 'level6']
# 15104/['level6' 'level8']
# 15105/['level6' 'level8']
# 15106/['level4' 'level6']
# 15107/['level4' 'level6']
# 15108/['level4' 'level6']
# 15109/['level6' 'level8']
# 15110/['rooms' 'level4' 'level6']
# 15111/['level6' 'level7' 'level8']
# 15112/['level4' 'level6']
# 15113/['level6' 'level8']
# 15114/['level4' 'level6']
# 15115/['level4' 'level6']
# 15116/['level6' 'level7' 'level8']
# 15117/['level6' 'level8']
# 15118/['level6' 'level8']
# 15119/['level6' 'level8']
# 15120/['description' 'level6' 'level8']
# 15121/['level6' 'level7' 'level8']
# 15122/['level4' 'level6']
# 15123/['level6' 'level7' 'level8']
# 15124/['level6' 'level7' 'level8']
# 15125/['level6' 'level7' 'level8']
# 15126/['level6' 'level8']
# 15127/['level6' 'level7' 'level8']
# 15128/['bathrooms' 'surface' 'level6' 'level7' 'level8']
# 15129/['level4' 'level6']
# 15130/['level6' 'level8']
# 15131/['level6' 'level8']
# 15132/['level4' 'level6']
# 15133/['level6' 'level7' 'level8']
# 15134/['surface' 'level6' 'level8']
# 15135/['level6' 'level7' 'level8']
# 15136/['level8']
# 15137/['level6' 'level7' 'level8']
# 15138/['level4' 'level6']
# 15139/['level7' 'level8']
# 15140/['level4' 'level6']
# 15141/['level6' 'level7' 'level8']
# 15142/['level6' 'level7' 'level8']
# 15143/['level6' 'level8']
# 15144/['level6' 'level8']
# 15145/['level6' 'level8']
# 15146/['level6' 'level8']
# 15147/['level6' 'level7' 'level8']
# 15148/['level4' 'level6']
# 15149/['level6' 'level8']
# 15150/['level6' 'level7' 'level8']
# 15151/['level6' 'level8']
# 15152/['level4' 'level6']
# 15153/['level6' 'level8']
# 15154/['level6' 'level8']
# 15155/['level6' 'level7' 'level8']
# 15156/['level6' 'level8']
# 15157/['level6' 'level8']
# 15158/['level4' 'level6']
# 15159/['level4' 'level6']
# 15160/['level4' 'level6']
# 15161/['level4' 'level6']
# 15162/['level4' 'level6']
# 15163/['level4' 'level6']
# 15164/['level4' 'level6']
# 15165/['level4' 'level6']
# 15166/['level6' 'level8']
# 15167/['level4' 'level6']
# 15168/['level4' 'level6']
# 15169/['level4' 'level6']
# 15170/['level4' 'level6']
# 15171/['level4' 'level6']
# 15172/['phone_realEstate' 'level4' 'level6']
# 15173/['level4' 'level6']
# 15174/['level6' 'level8']
# 15175/['level4' 'level6']
# 15176/['level4' 'level6']
# 15177/['level6' 'level8']
# 15178/['level4' 'level6']
# 15179/['level4' 'level6']
# 15180/['level4' 'level6']
# 15181/['level6' 'level8']
# 15182/['level4' 'level6']
# 15183/['surface' 'level6' 'level8']
# 15184/['level7' 'level8']
# 15185/['level4' 'level6']
# 15186/['level6' 'level8']
# 15187/['level4' 'level6']
# 15188/['surface' 'level6' 'level8']
# 15189/['level7' 'level8']
# 15190/['level4' 'level6']
# 15191/['level6' 'level8']
# 15192/['level6' 'level8']
# 15193/['level4' 'level6']
# 15194/['surface' 'level6' 'level8']
# 15195/['level4' 'level6']
# 15196/['level4' 'level6']
# 15197/['level4' 'level6']
# 15198/['level4' 'level6']
# 15199/['level4' 'level6']
# 15200/['level4' 'level6']
# 15201/['bathrooms' 'level6' 'level8']
# 15202/['level4' 'level6']
# 15203/['level4' 'level6']
# 15204/['level8']
# 15205/['level6' 'level7' 'level8']
# 15206/['level4' 'level6']
# 15207/['level6' 'level8']
# 15208/['level6' 'level7' 'level8']
# 15209/['level6' 'level8']
# 15210/['level6' 'level8']
# 15211/['level6' 'level8']
# 15212/['phone_realEstate' 'description' 'level6' 'level7' 'level8']
# 15213/['level4' 'level6']
# 15214/['level4' 'level6']
# 15215/['level6' 'level8']
# 15216/['phone_realEstate' 'level6' 'level8']
# 15217/['level6' 'level7' 'level8']
# 15218/['level4' 'level6']
# 15219/['level4' 'level6']
# 15220/['level4' 'level6']
# 15221/['level4' 'level6']
# 15222/['level6' 'level7' 'level8']
# 15223/['level6' 'level8']
# 15224/['level4' 'level6']
# 15225/['level4' 'level6']
# 15226/['level4' 'level6']
# 15227/['level6' 'level8']
# 15228/['level6' 'level8']
# 15229/['level6' 'level8']
# 15230/['phone_realEstate' 'level4' 'level6']
# 15231/['level4' 'level6']
# 15232/['level4' 'level6']
# 15233/['level4' 'level6']
# 15234/['level6' 'level7' 'level8']
# 15235/['level4' 'level6']
# 15236/['level4' 'level6']
# 15237/['rooms' 'bathrooms' 'level6' 'level8']
# 15238/['level6' 'level8']
# 15239/['level4' 'level6']
# 15240/['level4' 'level6']
# 15241/['phone_realEstate' 'level6' 'level7' 'level8']
# 15242/['level6' 'level7' 'level8']
# 15243/['level6' 'level8']
# 15244/['level6' 'level8']
# 15245/['level6' 'level8']
# 15246/['level6' 'level8']
# 15247/['level6' 'level8']
# 15248/['phone_realEstate' 'level4' 'level6']
# 15249/['level6' 'level8']
# 15250/['level4' 'level6']
# 15251/['level6' 'level8']
# 15252/['level6' 'level8']
# 15253/['level6' 'level7' 'level8']
# 15254/['level6' 'level7' 'level8']
# 15255/['level6' 'level7' 'level8']
# 15256/['level6' 'level7' 'level8']
# 15257/['level6' 'level7' 'level8']
# 15258/['level6' 'level7' 'level8']
# 15259/['level6' 'level7' 'level8']
# 15260/['level7' 'level8']
# 15261/['level6' 'level7' 'level8']
# 15262/['level6' 'level7' 'level8']
# 15263/['level6' 'level8']
# 15264/['level6' 'level7' 'level8']
# 15265/['rooms' 'bathrooms' 'level6' 'level8']
# 15266/['level6' 'level7' 'level8']
# 15267/['level6' 'level7' 'level8']
# 15268/['level6' 'level8']
# 15269/['level6' 'level8']
# 15270/['level6' 'level7' 'level8']
# 15271/['level6' 'level7' 'level8']
# 15272/['level6' 'level7' 'level8']
# 15273/['level4' 'level6']
# 15274/['level6' 'level8']
# 15275/['level6' 'level8']
# 15276/['level6' 'level8']
# 15277/['level4' 'level6']
# 15278/['level6' 'level8']
# 15279/['surface' 'level4' 'level6']
# 15280/['level4' 'level6']
# 15281/['level4' 'level6']
# 15282/['level6' 'level7' 'level8']
# 15283/['level4' 'level6']
# 15284/['level6' 'level8']
# 15285/['level6' 'level8']
# 15286/['level6' 'level7' 'level8']
# 15287/['level6' 'level8']
# 15288/['level4' 'level6']
# 15289/['surface' 'level6' 'level8']
# 15290/['level4' 'level6']
# 15291/['level6' 'level8']
# 15292/['level6' 'level7' 'level8']
# 15293/['level6' 'level7' 'level8']
# 15294/['level4' 'level6']
# 15295/['level6' 'level7' 'level8']
# 15296/['level6' 'level7' 'level8']
# 15297/['level4' 'level6']
# 15298/['level6' 'level7' 'level8']
# 15299/['level6' 'level7' 'level8']
# 15300/['level6' 'level7' 'level8']
# 15301/['level6' 'level7' 'level8']
# 15302/['level6' 'level8']
# 15303/['rooms' 'bathrooms' 'level6' 'level8']
# 15304/['rooms' 'bathrooms' 'level6' 'level8']
# 15305/['level6' 'level8']
# 15306/['surface' 'level4' 'level6']
# 15307/['level4' 'level6']
# 15308/['surface' 'level6' 'level8']
# 15309/['level6' 'level8']
# 15310/['level4' 'level6']
# 15311/['level4' 'level6']
# 15312/['level4' 'level6']
# 15313/['surface' 'level6' 'level8']
# 15314/['level4' 'level6']
# 15315/['level4' 'level6']
# 15316/['level6' 'level8']
# 15317/['level6' 'level8']
# 15318/['level6' 'level7' 'level8']
# 15319/['level4' 'level6']
# 15320/['rooms' 'level4' 'level6']
# 15321/['level6' 'level8']
# 15322/['level6' 'level8']
# 15323/['level4' 'level6']
# 15324/['level4' 'level6']
# 15325/['level6' 'level8']
# 15326/['phone_realEstate' 'level4' 'level6']
# 15327/['level6' 'level8']
# 15328/['surface' 'level4' 'level6']
# 15329/['level6' 'level8']
# 15330/['level4' 'level6']
# 15331/['level6' 'level7' 'level8']
# 15332/['description' 'level6' 'level8']
# 15333/['level6' 'level7' 'level8']
# 15334/['level4' 'level6']

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
ds = pd.read_csv('assets/real_estate.csv', sep=';')

# find null columns
dsNullColumns = ds.loc[:, ds.isnull().any()]

# remove null columns
dsWithNoNulls = ds.drop(columns=dsNullColumns.columns, axis=1)

print('original: ' + str(len(ds)) + 'x' + str(len(ds.columns)) + 
      ', without NAs: ' + str(len(dsWithNoNulls)) + 'x' + str(len(dsWithNoNulls.columns)))
# Out:
# original: 15335x37, without NAs: 15335x25

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
ds = pd.read_csv('assets/real_estate.csv', sep=';')

desiredPopulation = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

print(desiredPopulation['price'].mean())
# Out:
# 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Is the average of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
# TODO

# %% [markdown]
# #### Exercise 10. Is the average of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# TODO: Code

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# TODO

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# TODO

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# TODO

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# TODO: Code

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# TODO

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# TODO

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# TODO

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
